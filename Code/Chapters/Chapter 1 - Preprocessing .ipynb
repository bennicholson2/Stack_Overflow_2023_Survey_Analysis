# %% [markdown]
# Stack Overflow 2023 Survey Results EDA

# %%
#Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data Preprocessing

# %%
#Import survey results
data = pd.read_csv('/Users/ben_nicholson/Visual_Code_Projects/Personal_Projects/Stack_Overflow_2023/Data/survey_results_public.csv')
data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
#Print out the data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
data.shape[0] - data['AINextNeither different nor similar'].isna().sum()
# Out:
# 6599

# %% [markdown]
# After loading in the data, the biggest problem is that data ia quite messy. These are the following problems
# - Data Type Inconsistencies
# - Datatype of Columns
# - Missing Values
# - Column Names
# - Index

# %%
#Change the id so that it matches the column 'ResponseId'
data.set_index('ResponseId',inplace=True)
data
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
#Observe all of the columns that are present and get a better understanding of them
data.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %% [markdown]
# ### Split columns into categories for Database
#
# #### 1. Basic Information
# - MainBranch - Developer type
# - Age - Age range
# - Employment - Employment type
# - RemoteWork - Remote work
# - CodingActivities - Outside of work coding reason
# - Country - What country do you live in
# - Currency - Currency used
# - CompTotal - Numerical Yearly Salary
# - ConvertedCompYearly - Numerical Yearly Salary USD
# - WorkExp - Numberical years of work experience rounded to 5 years
# - ICorPM - Individual contributor or people manager
#
# #### 2. Education_Work_Company
# - EdLevel - Education level
# - LearnCode - How user learnt code
# - LearnCodeOnline - How have users learnt code online
# - LearnCodeCoursesCert - Online companies used to get certification
# - YearsCode - Numerical how many years spent coding
# - YearsCodePro - Numerical how many years has user spent coding professionally
# - DevType - Type of developer
# - OrgSize - Organisation number of employees
# - PurchaseInfluence - Company new purchases of technology
# - TechList - Company purchase new products
# - BuyNewTool - Company research new tools or softwares
# - Industry - Company industry is in
# - Professional Tech - What type of tools does company provide
# - TimeAnswering - Time spent answering questions at company
# - TimeSearching - Time spent looking for answers at company
#
# #### 3. Industry Culture
# - LanguageHaveWorkedWith - Programming languages used in past year
# - LanguageWantToWorkWith - Programming languages want to use next year
# - DatabaseHaveWorkedWith - Databases used in past year
# - DatabaseWantToWorkWith - Databases want to use in the next year
# - PlatformHaveWorkedWith - Cloud platforms used in the past year
# - PlatformWantToWorkWith - Cloud platforms for next year
# - WebframeHaveWorkedWith - Web frameworks used in the past year
# - WebframeWantToWorkWith - Web frameworks for next year
# - MiscTechHaveWorkedWith - Other frameworks/libraries used last year
# - MiscTechWantToWorkWith - Other frameworks/libraries for next year
# - ToolsTechHaveWorkedWith - Developer tools used last year
# - ToolsTechWantToWorkWith - Developer tools for next year
# - NEWCollabToolsHaveWorkedWith - Collaboration/code documentation tools used last year
# - NEWCollabToolsWantToWorkWith - Collaboration/code documentation tools for next year
# - AISearchHaveWorkedWith - AI-powered search tools used last year
# - AISearchWantToWorkWith - AI-powered search tools for next year
# - AIDevHaveWorkedWith - AI development tools used last year
# - AIDevWantToWorkWith - AI development tools for next year
# - OpSystemPersonal_use - Which operating system personal use
# - OpSysProfessional use - Which operating system professional use
# - OfficeStackAsyncHaveWorkedWith - Collaboration management tools used in past year
# - OfficeStackAsyncWantToWorkWith - Collaboration management want to use in next year
# - OfficeStackSyncHaveWorkedWith - Communication tools used to discuss in past year
# - OfficeStackSyncWantToWorkWith - Communication tools want to use in next year
# - AISearchHaveWorkedWith - AI search tool have used in past year
# - AISearchWantToWorkWith - AI search tool want to use in next year
# - AIDevHaveWorkedWith -  AI developer tool have used in past year
# - AIDevWantToWorkWith - AI developer tool want to use in next year
#
# #### 4. Stack Overflow
# - NEWOSites - Frequently visited websites from SO (drop)
# - SOAccount - Do you have a Stack Overflow account? (drop)
# - SOPartFreq - How frequently do you participate in Q&A on Stack Overflow? (Asking, answering, voting for, or commenting on questions) (drop)
# - SOComm - Do you consider yourself a member of the Stack Overflow community? (drop)
# - SOAI - Do you interact with the Stack Overflow community through the Stack Overflow AI, chatbots, or answering assistant? (drop)
# - TimeSearching - Weekly time spent searching on Stack Overflow. (drop)
# - TimeAnswering - Weekly time spent answering on Stack Overflow. (drop)
#
# #### 5. Artifical Intelligence
# - AISelect - Interaction methods with Stack Overflow AI.
# - AISent - Sentiment towards using AI on Stack Overflow.
# - AIAcc - Account status on Stack Overflow AI. (drop)
# - AIBen - Perception of AI's benefit on Stack Overflow.
# - AIToolInterested in Using - Interest in using AI for Stack Overflow.
# - AIToolCurrently Using - Current usage of AI on Stack Overflow.
# - AIToolNot interested in Using - Reasons for not using AI on Stack Overflow.
# - AINextVery_different - String How much will AI change your workflow (change col)
# - AINextSomewhat_different - String How much will AI change your workflow (change col)
# - AINextNeither_different_nor_similar - String How much will AI change your workflow (change col)
# - AINextSomewhat_similar - String How much will AI change your workflow (change col)
# - AINextVery_similar - String How much will AI change your workflow (change col)
# - SOVisitFreq - How frequently do you visit Stack Overflow or any Stack Exchange network site?
#
# #### 6. Work Culture
# - Knowledge_1 - Interaction with people outside your immediate team
# - Knowledge_2 - Knowledge is kept between teams
# - Knowledge_3 - Access to up to date information
# - Knowledge_4 - Existing answers to questions using tools
# - Knowledge_5 - Knowledge of system to use
# - Knowledge_6 - Repeated answering questions
# - Knowledge_7 - Wait time for answers
# - Knowledge_8 - Knowledge to work on any companies systems
# - Frequency_1 - Need help from outside your team
# - Frequency_2 - Interact with people outside your team (drop)
# - Frequency_3 - Frequency of knowledge being kept (drop)
#
# #### 7. Survey Review
# - SurveyEase - (drop)
# - SurveyLength - (drop)
# - TBranch - Participate in Developer Series (drop)
# - Q120 is the ackknowlegement that stack over flow can use your data - (drop)

# %%
#Drop the columns which have drop next to their name as they do not add to the EDA

columns_to_drop = [
    'Q120',
    'NEWSOSites',
    'SOAccount',
    'SOPartFreq',
    'SOComm',
    'SOAI',
    'TimeSearching',
    'TimeAnswering',
    'AIAcc',
    'Frequency_2',
    'Frequency_3',
    'SurveyEase',
    'SurveyLength',
    'TBranch'
]
data.drop(columns=columns_to_drop, inplace=True)
data
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1                            None of these     18-24 years old
# 2           I am a developer by profession     25-34 years old
# 3           I am a developer by profession     45-54 years old
# 4           I am a developer by profession     25-34 years old
# 5           I am a developer by profession     25-34 years old
# ...                                    ...                 ...
# 89180       I am a developer by profession     25-34 years old
# 89181       I am a developer by profession     18-24 years old
# 89182          I code primarily as a hobby   Prefer not to say
# 89183       I am a developer by profession  Under 18 years old
# 89184       I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# ...

# %%
#Split the dataframes into their separate sections

#Create columns for each new dataframe, these columns are listed above

#1. Basic Information
basic_info_columns = ['MainBranch', 'Age', 'Employment', 'RemoteWork', 'CodingActivities', 
                   'Country', 'Currency', 'CompTotal', 'ConvertedCompYearly', 'WorkExp', 'ICorPM']
basic_info_df = data[basic_info_columns]

#2. Education Work Company
edu_work_company_columns = ['EdLevel', 'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 
                               'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 
                               'TechList', 'BuyNewTool', 'Industry', 'ProfessionalTech']

edu_work_company_df = data[edu_work_company_columns]

#3. Industry Culture
industry_culture_columns = ['LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith', 
                         'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith', 'PlatformWantToWorkWith', 
                         'WebframeHaveWorkedWith', 'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith', 
                         'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 
                         'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'AISearchHaveWorkedWith', 
                         'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith', 
                         'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith', 
                         'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith', 
                         'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith', 'AISearchWantToWorkWith', 
                         'AIDevHaveWorkedWith', 'AIDevWantToWorkWith']
industry_culture_df = data[industry_culture_columns]

#4. Work Culture
work_culture_columns = ['Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4', 'Knowledge_5', 
                     'Knowledge_6', 'Knowledge_7', 'Knowledge_8', 'Frequency_1']

work_culture_df =data[work_culture_columns]

#5. Artificial Intelligence 
ai = ['AISelect', 'AISent', 'AIBen', 'AIToolInterested in Using', 'AIToolCurrently Using', 
                'AIToolNot interested in Using', 'AINextVery different', 'AINextSomewhat different', 
                'AINextNeither different nor similar', 'AINextSomewhat similar', 'AINextVery similar']

ai_df = data[ai]

# %% [markdown]
# ### 1. Basic Information
# This dataframe contains a lot of the most important information about the person. These include characteristics such as age, years of work experience and country which are all very important questions to consider when looking at the success of an individual's career. This dataframe contains a lot of different type of data, the goal is to go through and process the information so that it can be analysed. Have to also get the table into csv format which means removing certain aspects of the responses.

# %%
#Lets observe the dataframe and its columns to get a better idea of what it represents
basic_info_df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1                            None of these     18-24 years old
# 2           I am a developer by profession     25-34 years old
# 3           I am a developer by profession     45-54 years old
# 4           I am a developer by profession     25-34 years old
# 5           I am a developer by profession     25-34 years old
# ...                                    ...                 ...
# 89180       I am a developer by profession     25-34 years old
# 89181       I am a developer by profession     18-24 years old
# 89182          I code primarily as a hobby   Prefer not to say
# 89183       I am a developer by profession  Under 18 years old
# 89184       I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# ...

# %% [markdown]
# ### 1.1 Data handling: Columns with multiple responses
# The following columns need to be modified for analysis
# - MainBranch Categorical answer with 6 different responses that can be numbered 1-6
# - Employment Categorical answer that has option for multiple responses for one column which requires further normalisation
# - RemoteWork Categorical answer with 3 different responses that can be numbered 1-3
# - Coding Activities Categorical as well as nominal, this has an open ended question which is going to require NLP work to create a word count frequency.

# %%
#Create function that is used to get the different responses and create a numbered response that will be used to facilitate the new dataframe

def get_unique_response_values(df, column_list): 
    """
    Parameters:
    df is the dataframe that the unique values are coming from
    column_list is the list of columns that you would like to go through and get unique responses for
    """
    unique_values_dict = {}  # Dictionary to hold unique values for each column
    for col in column_list:
        unique_values_dict[col] = df[col].unique()  # Store unique values for each column
    
    # Find the maximum number of unique values among all columns
    max_unique_values = max(len(unique_values_dict[col]) for col in column_list)
    
    # Create an empty DataFrame with columns as specified in column_list
    empty_df = pd.DataFrame(columns=column_list)
    
    # Fill DataFrame with unique values
    for i in range(max_unique_values):
        row_data = {}
        for col in column_list:
            unique_values = unique_values_dict[col]
            if i < len(unique_values):
                row_data[col] = unique_values[i]
            else:
                row_data[col] = pd.NA  # Fill with NaN if uneven number of unique values
        empty_df = empty_df.append(row_data, ignore_index=True)
    
    return empty_df

# %%
basic_info_columns_numbered = ['MainBranch','Employment','RemoteWork','CodingActivities']
basic_info_df_numbered = get_unique_response_values(basic_info_df,basic_info_columns_numbered)
# Out:
# /var/folders/6q/lw13gkln44z1r6ncfrmcbc5w0000gn/T/ipykernel_11137/1953254461.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(row_data, ignore_index=True)
# /var/folders/6q/lw13gkln44z1r6ncfrmcbc5w0000gn/T/ipykernel_11137/1953254461.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(row_data, ignore_index=True)
# /var/folders/6q/lw13gkln44z1r6ncfrmcbc5w0000gn/T/ipykernel_11137/1953254461.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(row_data, ignore_index=True)
# ...

# %%
basic_info_df_numbered
# Out:
#                                             MainBranch  \
# 0                                        None of these
# 1                       I am a developer by profession
# 2    I am not primarily a developer, but I write co...
# 3                          I code primarily as a hobby
# 4                                I am learning to code
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#                                             Employment  \
# 0                                                  NaN
# 1                                  Employed, full-time
# 2    Employed, full-time;Independent contractor, fr...
# 3                   Not employed, but looking for work
# ...

# %% [markdown]
# ### Problem with function
# Notice how columns 'MainBranch' and 'RemoteWork' have returned reasonable length responses, however 'Employment' had the option has multiple responses for each column and 'CodingActivties' allowed for open ended responses.
#
# #### 1.1.1 Employment Column

# %% [markdown]
# Employment is made up of 9 different options, however multiple answers can be chosen. The problem with this is that there are 9! ways that a user could have responded to this question. To overcome this issue, there a few methods.
# 1. Duplicate responses
#
# This would result in the duplication of data for each different response. For example if the respondent had 'Employed, full time' and 'Independent contractor' this would result in two new columns. This would be effective in getting a count of the type of employment however, this creates data dependencies. If a lot of the higher income earners are doing multiple jobs at once then it would result in it seeming that the average income would be higher than what it is. As keeping the integrity of the SO data survey is integral to analysis another handling technique is going to be required.
#
# 2. Dummy Variables
#
# Using a dummy variable would create a new column that has a binary indicator of the variables for each option. This is one that might have practical issues. However you could keep the integrity of the other data points and be able to get a count of the different types of employment. This is going to work better for the data.
#
# A word count is not necessary as it was not an open response to the question. So creating, 9 new dummy variables where they are as the following
# - Employment, full time
# - Employed, part-time
# - Independent contractor, freelancer, or self-employed
# - Not employed, but looking for work
# - Not employed, and not looking for work
# - Student, full-time
# - Student, part-time
# - Retired
# - I prefer not to say

# %%
import pandas as pd

def preprocess_df_column(dataframe, column_name):
    """
    Preprocesses the 'Employment' column in the given DataFrame by replacing commas,
    creating dummy variables, concatenating them with the original DataFrame, and filling NaN values with 0.
    
    Parameters:
    dataframe (DataFrame): The DataFrame containing the 'Employment' column.
    column_name (str): The name of the column to preprocess.
    
    Returns:
    DataFrame: The updated DataFrame with preprocessed 'Employment' column.
    """
    # Copy the DataFrame to avoid modifying the original
    df = dataframe.copy()
    
    # Replace commas in the 'Employment' column
    df[column_name] = df[column_name].astype(str).str.replace(',', '')

    # Create dummy variables
    dummy_df = df[column_name].str.get_dummies(sep=';')

    # Concatenate the dummy variables with the original DataFrame
    df = pd.concat([df, dummy_df], axis=1)

    # Fill NaN values with 0
    df = df.fillna(0)

    return df

# %%
basic_info_df_with_employment_dummies = preprocess_df_column(basic_info_df,'Employment')
basic_info_df_with_employment_dummies.drop(columns=['I prefer not to say','nan'],inplace=True)
basic_info_df_with_employment_dummies
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1                            None of these     18-24 years old
# 2           I am a developer by profession     25-34 years old
# 3           I am a developer by profession     45-54 years old
# 4           I am a developer by profession     25-34 years old
# 5           I am a developer by profession     25-34 years old
# ...                                    ...                 ...
# 89180       I am a developer by profession     25-34 years old
# 89181       I am a developer by profession     18-24 years old
# 89182          I code primarily as a hobby   Prefer not to say
# 89183       I am a developer by profession  Under 18 years old
# 89184       I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         nan
# ...

# %% [markdown]
# The function above has created a dataframe that includes dummy variables and has successfully create a binary response for the type of employment a user has. This can now be used in better analysis.

# %% [markdown]
# ### 1.1.2 CodingActivties Column
# This column has 8 responses, where 7 of which are categorical. However, the last response is an open ended question. The goal of this is to use a NLP to create a word count of the phrases that were used. Once the word count is created

# %%
preprocess_df_column(basic_info_columns,'CodingActivities')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/6q/lw13gkln44z1r6ncfrmcbc5w0000gn/T/ipykernel_11137/524353339.py in <module>
# ----> 1 preprocess_df_column(basic_info_columns,'CodingActivities')
#
# /var/folders/6q/lw13gkln44z1r6ncfrmcbc5w0000gn/T/ipykernel_11137/1106723903.py in preprocess_df_column(dataframe, column_name)
#      17
#      18     # Replace commas in the 'Employment' column
# ---> 19     df[column_name] = df[column_name].astype(str).str.replace(',', '')
#      20
#      21     # Create dummy variables
#
# TypeError: list indices must be integers or slices, not str

# %%
#Convert all of these to CSV then continue data work in SQL
basic_info_df.to_csv('/Users/ben_nicholson/Visual_Code_Projects/Personal_Projects/Stack_Overflow_2023_Survey_Analysis/Code/Database Tables/basic_information.csv')
edu_work_company_df.to_csv('/Users/ben_nicholson/Visual_Code_Projects/Personal_Projects/Stack_Overflow_2023_Survey_Analysis/Code/Database Tables/education_work_company.csv')
industry_culture_df.to_csv('/Users/ben_nicholson/Visual_Code_Projects/Personal_Projects/Stack_Overflow_2023_Survey_Analysis/Code/Database Tables/industry_culture.csv')
work_culture_df.to_csv('/Users/ben_nicholson/Visual_Code_Projects/Personal_Projects/Stack_Overflow_2023_Survey_Analysis/Code/Database Tables/work_culture.csv')
ai_df.to_csv('/Users/ben_nicholson/Visual_Code_Projects/Personal_Projects/Stack_Overflow_2023_Survey_Analysis/Code/Database Tables/artifical_intelligence.csv')
